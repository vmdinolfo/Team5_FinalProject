# %%
# import required libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import pandas as pd
import os
import imblearn
from imblearn.over_sampling import SMOTE
import joblib
import numpy as np

# %%
# load stroke positive data subset
stroke_subset = pd.read_csv("data/combined_subsets.csv")
stroke_subset
# Out:
#           id  gender   age  hypertension  heart_disease  ever_married  \
# 0       9046       1  67.0             0              1             1
# 1      31112       1  80.0             0              1             1
# 2      60182       0  49.0             0              0             1
# 3       1665       0  79.0             1              0             1
# 4      56669       1  81.0             0              0             1
# ...      ...     ...   ...           ...            ...           ...
# 29067  56196       0  10.0             0              0             0
# 29068   5450       0  56.0             0              0             1
# 29069  28375       0  82.0             1              0             1
# 29070  27973       1  40.0             0              0             1
# 29071  36271       0  82.0             0              0             1
#
#        work_type  Residence_type  avg_glucose_level   bmi  smoking_status  \
# 0              0               0             228.69  36.6               1
# 1              0               1             105.92  32.5               0
# 2              0               0             171.23  34.4               2
# 3              1               1             174.12  24.0               0
# 4              0               0             186.21  29.0               1
# ...          ...             ...                ...   ...             ...
# 29067          2               0              58.64  20.4               0
# 29068          3               0             213.61  55.4               1
# 29069          0               0              91.94  28.9               1
# 29070          0               0              99.16  33.2               0
# 29071          0               0              79.48  20.6               0
#
#        stroke
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 29067       0
# 29068       0
# 29069       0
# 29070       0
# 29071       0
#
# [29072 rows x 12 columns]

# %%
stroke_subset.shape
# Out:
# (29072, 12)

# %%
# target
target = stroke_subset["stroke"]
target_names = ["no", "yes"]

# features
stroke_data = stroke_subset.drop(["stroke","id"], axis=1)
feature_names = stroke_data.columns

stroke_data.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          0
# 1       1  80.0             0              1             1          0
# 2       0  49.0             0              0             1          0
# 3       0  79.0             1              0             1          1
# 4       1  81.0             0              0             1          0
#
#    Residence_type  avg_glucose_level   bmi  smoking_status
# 0               0             228.69  36.6               1
# 1               1             105.92  32.5               0
# 2               0             171.23  34.4               2
# 3               1             174.12  24.0               0
# 4               0             186.21  29.0               1

# %%
sm = SMOTE()
stroke_data, target = sm.fit_resample(stroke_data,target)

# %%
model_RF = joblib.load('RF_model.sav')
result_RF = model_RF.predict(stroke_data)
print(classification_report(target, predictions,
                            target_names=["No Stroke", "Stroke"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5ed89c97f905> in <module>
#       1 model_RF = joblib.load('RF_model.sav')
#       2 result_RF = model_RF.predict(stroke_data)
# ----> 3 print(classification_report(target, predictions,
#       4                             target_names=["No Stroke", "Stroke"]))
#
# NameError: name 'predictions' is not defined

# %%
from sklearn.metrics import classification_report

predictions = model_RF.predict(stroke_data)

print(classification_report(target, predictions,
                            target_names=["No Stroke", "Stroke"]))
# Out:
#               precision    recall  f1-score   support
#
#    No Stroke       0.99      0.99      0.99     28524
#       Stroke       0.99      0.99      0.99     28524
#
#     accuracy                           0.99     57048
#    macro avg       0.99      0.99      0.99     57048
# weighted avg       0.99      0.99      0.99     57048

# %%
test = [1,67,0,1,1,0,0,228.7,36.6,1]

test_ar = np.array(test)
test_ar = test_ar.reshape(1,-1)

# %%
predictions = model_RF.predict(test_ar)
predictions
# Out:
# array([1], dtype=int64)
